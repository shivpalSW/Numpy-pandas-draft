# %%
KNN - (K - Nearest Neighbours)

    Supervised machine learning algo.
    KNN is used for both classification & regression
    It is called as voting classifier
    Distance based,non probabilstic, non logistic algorithm.
    It is also called as lazy learner
    It is slow bcz it takes alot of time calculating the distances with each sample
    Voting classifier is used to devote class to the testing values
    
    where, 
    k >> no. of neighbours

# %% [markdown]
# ## Formulas for distance calculation:

# %% [raw]
# 1. Euclidean distance:

# %%
from IPython.display import Image

# %%
Image('Euclidean-Distance.png',width=500,height=500)

# %% [raw]
# 2. Manhattan Distance

# %%
Image('Manhattan.png',width=400,height=400)

# %%
Image('difference.png')

# %% [raw]
# For KNN Regression:
#     It calculated the mean of k nearest sample's tagrgeted feature values.
