# %%
Naive Bayes is a supervised machine learning algorithm.
Is used for classification problems.
It is called Naive beacause it assumes that all the independent features are new meaning that they are independent to each other.
It is a probabilistic Algorithm.
It is one of the most widly used algorithm for document classification.

# %%
from IPython.display import Image
Image('bayes thorem.png',width=400,height=400)

# %%
Bayes Theorem:
    
    P(A/B) = P(B/A) * P(A) / P(B)

# %%
Bayes theorem used in machine learning:
    
P(Y/X1,X2,X3)   = P(X1/Y)*P(X2/Y)*P(X3/Y) * P(Y)  /  P(X1)*P(X2)*P(X3)

# %%
import pandas as pd
df= pd.read_csv('weather.csv')
df
# Out:
#      outlook temperature humidity  windy play
# 0   overcast         hot     high  False  yes
# 1   overcast        cool   normal   True  yes
# 2   overcast        mild     high   True  yes
# 3   overcast         hot   normal  False  yes
# 4      rainy        mild     high  False  yes
# 5      rainy        cool   normal  False  yes
# 6      rainy        cool   normal   True   no
# 7      rainy        mild   normal  False  yes
# 8      rainy        mild     high   True   no
# 9      sunny         hot     high  False   no
# 10     sunny         hot     high   True   no
# 11     sunny        mild     high  False   no
# 12     sunny        cool   normal  False  yes
# 13     sunny        mild   normal   True  yes

# %%
df_sunny = pd.read_clipboard()
df_sunny
# Out:
#   Condition  Yes  No P(Yes)  P(No)
# 0     Sunny    2   3    2/9    3/5
# 1     Rainy    3   2    1/3    2/5
# 2  Overcast    4   0    4/9  0
# 3     Total    9   5   100%   100%

# %%
df_sunny.to_csv('df_sunny.csv')
df_hot.to_csv('df_hot.csv')

# %%
df_hot= pd.read_clipboard()
df_hot
# Out:
#   Condition  Yes  No P(Yes) P(No)
# 0       hot    2   2    2/9   2/5
# 1      cool    3   1    1/3   1/5
# 2      mild    4   2    4/9   2/5
# 3     Total    9   5   100%  100%

# %%
P(Yes/ Sunny * Hot) = P(Sunny/Yes) * P(Hot/Yes) * P( Yes) / P(sunny) * P(Hot)

# %%
2/9 * 9/14 * 2/9
# Out:
# 0.031746031746031744

# %%
P(No/ Sunny * Hot) = P(Sunny/No) * P(Hot/No) * P(No) / P(sunny) * P(Hot)

# %%
3/5 * 2/5  * 5/14
# Out:
# 0.08571428571428572

# %%
Play (Yes) = P(Yes/ Sunny * Hot)/P(Yes/ Sunny * Hot) + P(No/ Sunny * Hot)

# %%
play (yes) = 0.031746031746031744/(0.031746031746031744 + 0.08571428571428572)

# %%
no=0.08571428571428572/(0.031746031746031744 + 0.08571428571428572)
no*100
# Out:
# 72.97297297297297

# %%
yes=0.031746031746031744/(0.031746031746031744 + 0.08571428571428572)
100*yes
# Out:
# 27.027027027027025

# %%
play (yes) = 0.27027027027027023 * 100 = 27.02%

# %%
play (No) = 72.97%

# %%
                 Yes  No
Probabilities  [0.90 0.10]   >> Yes
               [0.27 0.73]   >> No

# %%
Laplace Correction in machine learning >> is also called as zero frequency problem.

# %%
Types:
    Multinomial Naive Bayes algorithm
    Gaussian Naive Bayes Algorithm
    BernoulliNB Algorithm

# %%
Assumptions:
    1. Featiures are independent of each other.
    2. targeted column is categorical in nature.
    
Applications:
    1. Spam Mail detection.
    2. Document Classification
    3. Whether forecast
    4. Movie Review
    5. News classifier
    6. Disorder classification
    
Advantages:
    1. Works well on categorical data.
    2. doesnt required nomalization
    3. It is fastest algorithm, no complicated matheatical calculations involved.
    4. Is good with higher dimensions compared to other algorithms.
    5. Performs well on small dataset as well.
    6. Ut is robust to outliers.
    7. Impact of null values is negligible. Bcz it cna handle missing data. Attributes are handled separatly by the algorithms at both model construction time & prediction time. It ignores the missing data while calculationsng the probabilities during training & so is ignored when probability is calculated for class value.

Disadvantages:
    1. It needs Laplace correction when the probabilities are zero.
    2. Assumption of independence.
