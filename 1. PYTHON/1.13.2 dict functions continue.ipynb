# %%
marks={'Maths': 90, 'Physics': 90, 'Bio': 93, 'Che': 95, 'History': 89}

keys=list(marks.keys())
values=list(marks.values())

print(keys)
print(values)
dict1={}
for i in range(len(keys)):
    for j in range(i+1,len(keys)):
        if values[i]>values[j]:
            values[i],values[j]=values[j],values[i]
            keys[i],keys[j]=keys[j],keys[i]

dict(zip(keys,values))
# Out:
# ['Maths', 'Physics', 'Bio', 'Che', 'History']
# [90, 90, 93, 95, 89]
# {'History': 89, 'Physics': 90, 'Maths': 90, 'Bio': 93, 'Che': 95}

# %% [markdown]
# ## fromkeys

# %% [raw]
# fromkeys(sequence,[Value])
# default value is none

# %%
dict.fromkeys(['a','e','i','o','u'])
# Out:
# {'a': None, 'e': None, 'i': None, 'o': None, 'u': None}

# %%
dict.fromkeys(['a','e','i','o','u'],'Vowels')
# Out:
# {'a': 'Vowels', 'e': 'Vowels', 'i': 'Vowels', 'o': 'Vowels', 'u': 'Vowels'}

# %%
dict.fromkeys(['a','e','i','o','u'],[100,200])
# Out:
# {'a': [100, 200],
#  'e': [100, 200],
#  'i': [100, 200],
#  'o': [100, 200],
#  'u': [100, 200]}

# %% [markdown]
# ## Setdefault()

# %% [raw]
# Returns a value with specified key if key is present
# returns none if key is not present
# If key is not present then we can also assign a new key value pair

# %%
marks={'Maths': 90, 'Physics': 90, 'Bio': 93, 'Che': 95, 'History': 89}

marks.setdefault('Maths')
# Out:
# 90

# %%
marks.setdefault('Geography')

# %%
marks.setdefault('Geo',99)
# Out:
# 99

# %%
marks
# Out:
# {'Maths': 90,
#  'Physics': 90,
#  'Bio': 93,
#  'Che': 95,
#  'History': 89,
#  'Geography': None,
#  'Geo': 99}

# %%
sub_marks=marks.copy()
sub_marks
# Out:
# {'Maths': 90,
#  'Physics': 90,
#  'Bio': 93,
#  'Che': 95,
#  'History': 89,
#  'Geography': None,
#  'Geo': 99}

# %%
Dict functions

# dict1[keys]=value
update()
get()
pop()
popitem()
clear()
del
.keys()
.values()
.items()
fromkeys()
setdefault()
zip()
sorted
collects, Counter
copy()

# %%
from copy import deepcopy
a = (1,2,3,6,5,4,8) 
b = a
c=(1,2)
b=b+c
b,a
# Out:
# ((1, 2, 3, 6, 5, 4, 8, 1, 2), (1, 2, 3, 6, 5, 4, 8))

# %%
a = (1,2,3,6,5,4,8) 
b = a
c=(1,2)
a=a+c
b,a
# Out:
# ((1, 2, 3, 6, 5, 4, 8), (1, 2, 3, 6, 5, 4, 8, 1, 2))

# %%
l1=[1,2]
l2=l1
l2.append(100)
l1,l2
# Out:
# ([1, 2, 100], [1, 2, 100])

# %%
l1=[1,2]
l2=l1.copy()
l2.append(100)
l1,l2
# Out:
# ([1, 2], [1, 2, 100])
