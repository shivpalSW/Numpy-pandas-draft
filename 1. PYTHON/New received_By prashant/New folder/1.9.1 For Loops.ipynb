# %% [raw]
# For loop
# While Loop
#
# same functionalities but differnet syntax
# execute set of sentences
# They work like an iterator
# can be used on String, List , Tuple, Set, Dict, Range, Pandas Series, Numpy etc...

# %% [raw]
# Syntax of for loop
# For (item of the iterator) in (/enumerate)(iterator name)/range:
#     statements...

# %%
vari = 'Python'
for item in range(5):
    print(vari)
# Out:
# Python
# Python
# Python
# Python
# Python

# %% [markdown]
# Enumerate Function

# %%
for index, value in enumerate('Python'):
    print(index,value)
# Out:
# 0 P
# 1 y
# 2 t
# 3 h
# 4 o
# 5 n

# %%
for index in enumerate('Python'):
    print(index)
# Out:
# (0, 'P')
# (1, 'y')
# (2, 't')
# (3, 'h')
# (4, 'o')
# (5, 'n')

# %% [markdown]
# Range Function

# %%
n=int(input("enter any num: "))
for i in range(n):print('a')
# Out:
# enter any num: 5
# a
# a
# a
# a
# a

# %%
[(i) for i in 'Number']
# Out:
# ['N', 'u', 'm', 'b', 'e', 'r']
