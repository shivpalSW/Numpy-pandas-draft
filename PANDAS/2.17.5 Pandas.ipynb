# %% [raw]
# Multiple ways to create a dataframe:
#     1. excel
#     2. Json
#     3. CSV
#     4. MongoDB Database
#     5. SQL database
#     6. List
#     7. Dict
#     8. Numpy array

# %%
import pandas as pd
import numpy as np

# %%
data={'column A':[3,4,5,6],'column B':[9,8,3,1]}
dataframe=pd.DataFrame(data)

# %%
dataframe
# Out:
#    column A  column B
# 0         3         9
# 1         4         8
# 2         5         3
# 3         6         1

# %% [raw]
# coloumns in dataframe are also refered as features, dimensions, variables or fields.
# rows are also refered as records, values, observations, index_values

# %% [markdown]
# # Empty Dataframe

# %%
df= pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['column C'] = [10,20,40,30]
df
# Out:
#    column C
# 0        10
# 1        20
# 2        40
# 3        30

# %%
df['column D'] = 'Python'
df
# Out:
#    column C column D
# 0        10   Python
# 1        20   Python
# 2        40   Python
# 3        30   Python

# %%
df['column D'] = list('Pyth')
df
# Out:
#    column C column D
# 0        10        P
# 1        20        y
# 2        40        t
# 3        30        h

# %%
df['column E'] = np.array([10,60,40,50])
df
# Out:
#    column C column D  column E
# 0        10        P        10
# 1        20        y        60
# 2        40        t        40
# 3        30        h        50

# %% [markdown]
# # Loadiing the data - Reading CSV file

# %%
df=pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### checking the size of the dataframe

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
for column in df.columns:
    print(column)
# Out:
# Id
# SepalLengthCm
# SepalWidthCm
# PetalLengthCm
# PetalWidthCm
# Species

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=150, step=1),
#  Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#         'Species'],
#        dtype='object')]

# %%
len(df.columns),df.shape[1]
# Out:
# (6, 6)

# %%
len(df.index),df.shape[0]
# Out:
# (150, 150)

# %%
df1=df.head()   #defult value is 5

# %%
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ## Export the data-- csv & xlsx

# %%
df.describe().to_csv('Describe.csv')

# %%
df.describe().to_excel('Describe.xlsx')

# %%
df.describe()[1:2]['SepalLengthCm']
# Out:
# mean    5.843333
# Name: SepalLengthCm, dtype: float64

# %%
df.describe()[1:2][['SepalLengthCm','PetalLengthCm']]
# Out:
#       SepalLengthCm  PetalLengthCm
# mean       5.843333       3.758667

# %%
df.describe()[:1]
# Out:
#           Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.0          150.0         150.0          150.0         150.0

# %% [markdown]
# ## slicing

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df[0:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
df[80:100]
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 80   81            5.5           2.4            3.8           1.1
# 81   82            5.5           2.4            3.7           1.0
# 82   83            5.8           2.7            3.9           1.2
# 83   84            6.0           2.7            5.1           1.6
# 84   85            5.4           3.0            4.5           1.5
# 85   86            6.0           3.4            4.5           1.6
# 86   87            6.7           3.1            4.7           1.5
# 87   88            6.3           2.3            4.4           1.3
# 88   89            5.6           3.0            4.1           1.3
# 89   90            5.5           2.5            4.0           1.3
# 90   91            5.5           2.6            4.4           1.2
# 91   92            6.1           3.0            4.6           1.4
# 92   93            5.8           2.6            4.0           1.2
# ...

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df[['SepalLengthCm','SepalWidthCm']]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
df[['SepalLengthCm','SepalWidthCm']][2:5]
# Out:
#    SepalLengthCm  SepalWidthCm
# 2            4.7           3.2
# 3            4.6           3.1
# 4            5.0           3.6

# %%
df[2:5][['SepalLengthCm','SepalWidthCm']]
# Out:
#    SepalLengthCm  SepalWidthCm
# 2            4.7           3.2
# 3            4.6           3.1
# 4            5.0           3.6

# %% [markdown]
# ### loc fucntion

# %%
'it accesses the actual values at the index & columns'

# %%
df.loc[2:5]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df2=df.set_index('Id').loc[2:5]
df2
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df2.loc[4:9]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.loc[:,['SepalLengthCm','SepalWidthCm']]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
df=df.loc[2:5,['SepalLengthCm','PetalWidthCm']]
df
# Out:
#    SepalLengthCm  PetalWidthCm
# 2            4.7           0.2
# 3            4.6           0.2
# 4            5.0           0.2
# 5            5.4           0.4

# %%
df=pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## iloc

# %% [raw]
# index has to be passed in iloc function

# %%
df.iloc[3:6]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.loc[:,['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',]]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[2:5,1:3]
# Out:
#    SepalLengthCm  SepalWidthCm
# 2            4.7           3.2
# 3            4.6           3.1
# 4            5.0           3.6

# %%
df.iloc[2:30:3,-1:-6:-2]
# Out:
#             New  PetalLengthCm  SepalLengthCm
# 2   Iris-setosa            1.3            4.7
# 5   Iris-setosa            1.7            5.4
# 8   Iris-setosa            1.4            4.4
# 11  Iris-setosa            1.6            4.8
# 14  Iris-setosa            1.2            5.8
# 17  Iris-setosa            1.4            5.1
# 20  Iris-setosa            1.7            5.4
# 23  Iris-setosa            1.7            5.1
# 26  Iris-setosa            1.6            5.0
# 29  Iris-setosa            1.6            4.7

# %%
df.iloc[2,1]
# Out:
# 4.7

# %%
df.iloc[2,3]=2.3
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            2.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#                 New
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
array=np.random.randint(10,100,size=(5,5))
array
# Out:
# array([[74, 40, 56, 44, 95],
#        [67, 11, 91, 90, 66],
#        [10, 90, 47, 12, 71],
#        [89, 36, 67, 67, 29],
#        [76, 13, 56, 37, 87]])

# %%
array_df=pd.DataFrame(array,columns=['a','b','c','d','e'],index=list('ABCDE'))
array_df
# Out:
#     a   b   c   d   e
# A  74  40  56  44  95
# B  67  11  91  90  66
# C  10  90  47  12  71
# D  89  36  67  67  29
# E  76  13  56  37  87

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['SepalLengthCm'])
# Out:
# pandas.core.series.Series

# %%
df['SepalLengthCm'].dtype
# Out:
# dtype('float64')
