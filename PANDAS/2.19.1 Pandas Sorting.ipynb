# %% [raw]
# importing & exporting data
# shape
# size
# info
# describe
# dataframe from list dict etc..
# head tail
# loc iloc
# columns, index, axes
# setting index, resetting index
# changin values by using iloc
# type
# dtype

# %% [markdown]
# ## Sorting

# %%
import pandas as pd
import numpy as np

# %% [raw]
# sort_index()
# sort_values()
# set_index()
# reset_index()

# %%
df= pd.read_csv('Emp_Records.csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02           60.0             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02           60.0             NaN   51063
# 2  428945        Joe       54.15           68.0            0.98   50155
# 3  408351      Diane       39.67            NaN           18.30  180294
# 4  193819   Benjamin       40.31           58.0            4.01  117642
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
df.describe()
# Out:
#              Emp ID  Age in Yrs  Weight in Kgs  Age in Company         Salary
# count     100.00000  100.000000      98.000000       99.000000     100.000000
# mean   547652.10000   39.238700      58.132653        8.978081  119738.090000
# std    257664.16679   12.066252      12.397737        8.701416   46185.278194
# min    134841.00000   21.100000      40.000000        0.020000   42005.000000
# 25%    328643.75000   28.177500      50.000000        2.045000   83979.750000
# 50%    497414.00000   37.595000      56.000000        5.930000  118049.500000
# 75%    766040.00000   49.900000      61.750000       13.845000  162509.250000
# max    979607.00000   59.470000      90.000000       34.520000  197537.000000

# %%
df.size
# Out:
# 700

# %%
df.shape
# Out:
# (100, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      100 non-null    float64
#  3   Weight in Kgs   98 non-null     float64
#  4   Age in Company  99 non-null     float64
#  5   Salary          100 non-null    int64
#  6   City            100 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
df.isnull().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     2
# Age in Company    1
# Salary            0
# City              0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     2
# Age in Company    1
# Salary            0
# City              0
# dtype: int64

# %%
df['Salary'].min(),df['Salary'].max()
# Out:
# (42005, 197537)

# %%
df.fillna(df.mean())
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36      58.132653       13.680000  168251
# 1   940761     Brenda       47.02      60.000000        8.978081   51063
# 2   428945        Joe       54.15      68.000000        0.980000   50155
# 3   408351      Diane       39.67      58.132653       18.300000  180294
# 4   193819   Benjamin       40.31      58.000000        4.010000  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82      89.000000        1.050000  129774
# 96  704709     Harold       32.61      77.000000        5.930000  156194
# 97  461593     Nicole       52.66      60.000000       28.530000   95673
# 98  392491    Theresa       29.60      57.000000        6.990000   51015
# 99  495141      Tammy       38.38      55.000000        2.260000   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02           60.0             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_index(axis=0)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02           60.0             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_index(axis=1)
# Out:
#     Age in Company  Age in Yrs          City  Emp ID First Name  Salary  \
# 0            13.68       36.36        Denver  677509       Lois  168251
# 1              NaN       47.02     Stonewall  940761     Brenda   51063
# 2             0.98       54.15  Michigantown  428945        Joe   50155
# 3            18.30       39.67      Hydetown  408351      Diane  180294
# 4             4.01       40.31       Fremont  193819   Benjamin  117642
# ..             ...         ...           ...     ...        ...     ...
# 95            1.05       22.82        Biloxi  639892       Jose  129774
# 96            5.93       32.61  Carol Stream  704709     Harold  156194
# 97           28.53       52.66       Detroit  461593     Nicole   95673
# 98            6.99       29.60      Mc Grath  392491    Theresa   51015
# 99            2.26       38.38          Alma  495141      Tammy   93650
#
#     Weight in Kgs
# 0             NaN
# 1            60.0
# 2            68.0
# 3             NaN
# ...

# %%
df.T
# Out:
#                     0          1             2         3         4   \
# Emp ID          677509     940761        428945    408351    193819
# First Name        Lois     Brenda           Joe     Diane  Benjamin
# Age in Yrs       36.36      47.02         54.15     39.67     40.31
# Weight in Kgs      NaN       60.0          68.0       NaN      58.0
# Age in Company   13.68        NaN          0.98      18.3      4.01
# Salary          168251      51063         50155    180294    117642
# City            Denver  Stonewall  Michigantown  Hydetown   Fremont
#
#                        5        6            7        8               9   ...  \
# Emp ID             499687   539712       380086   477616          162402  ...
# First Name        Patrick    Nancy        Carol  Frances           Diana  ...
# Age in Yrs          34.86    22.14        59.12    58.18           29.73  ...
# Weight in Kgs        58.0     50.0         40.0     42.0            60.0  ...
# ...

# %%
(df.T).sort_index(axis=0)
# Out:
#                     0          1             2         3         4   \
# Age in Company   13.68        NaN          0.98      18.3      4.01
# Age in Yrs       36.36      47.02         54.15     39.67     40.31
# City            Denver  Stonewall  Michigantown  Hydetown   Fremont
# Emp ID          677509     940761        428945    408351    193819
# First Name        Lois     Brenda           Joe     Diane  Benjamin
# Salary          168251      51063         50155    180294    117642
# Weight in Kgs      NaN       60.0          68.0       NaN      58.0
#
#                        5        6            7        8               9   ...  \
# Age in Company      12.02     0.87        34.52    23.27            3.44  ...
# Age in Yrs          34.86    22.14        59.12    58.18           29.73  ...
# City            Macksburg  Atlanta  Blanchester  Delmita  Eureka Springs  ...
# Emp ID             499687   539712       380086   477616          162402  ...
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02           60.0             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
dataframe=df.set_index('Age in Yrs').sort_index(axis=0,ascending=False)

# %%
dataframe
# Out:
#             Emp ID First Name  Weight in Kgs  Age in Company  Salary  \
# Age in Yrs
# 59.47       441771     Cheryl           47.0           26.69   92220
# 59.42       560455    Carolyn           53.0           16.08   42005
# 59.27       515103       Anne           48.0           14.01  114426
# 59.12       380086      Carol           40.0           34.52   60918
# 58.43       528673       Paul           60.0           22.10  145235
# ...            ...        ...            ...             ...     ...
# 22.21       153989       Jack           61.0            0.56   82965
# 22.14       539712      Nancy           50.0            0.87   98189
# 21.93       750173    Antonio           82.0            0.24  181646
# 21.30       879753     Pamela           47.0            0.13  149262
# 21.10       301576      Wayne           87.0            0.02   92758
#
#                    City
# Age in Yrs
# 59.47          Quecreek
# 59.42       Saint Cloud
# 59.27        Cookeville
# ...

# %%
dataframe=dataframe.reset_index()

# %%
dataframe
# Out:
#     Age in Yrs  Emp ID First Name  Weight in Kgs  Age in Company  Salary  \
# 0        59.47  441771     Cheryl           47.0           26.69   92220
# 1        59.42  560455    Carolyn           53.0           16.08   42005
# 2        59.27  515103       Anne           48.0           14.01  114426
# 3        59.12  380086      Carol           40.0           34.52   60918
# 4        58.43  528673       Paul           60.0           22.10  145235
# ..         ...     ...        ...            ...             ...     ...
# 95       22.21  153989       Jack           61.0            0.56   82965
# 96       22.14  539712      Nancy           50.0            0.87   98189
# 97       21.93  750173    Antonio           82.0            0.24  181646
# 98       21.30  879753     Pamela           47.0            0.13  149262
# 99       21.10  301576      Wayne           87.0            0.02   92758
#
#            City
# 0      Quecreek
# 1   Saint Cloud
# 2    Cookeville
# 3   Blanchester
# ...

# %%
df.set_index('First Name',inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-6297e559efc3> in <module>
# ----> 1 df.set_index('First Name',inplace=True)
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['First Name'] are in the columns"

# %%
df.sort_index(axis=0,inplace=True)

# %%
df
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Aaron       218791       48.49           56.0           20.08   54402
# Alan        247137       38.65           80.0           11.15  154810
# Amanda      227922       35.02           40.0           10.28  114257
# Amy         893212       36.14           52.0           14.17  112715
# Andrea      183071       32.08           52.0            7.28   54179
# ...            ...         ...            ...             ...     ...
# Theresa     214352       24.66           59.0            2.52  197537
# Thomas      622406       49.85           73.0           19.15   73862
# Todd        917937       25.93           74.0            1.22  163560
# Wayne       301576       21.10           87.0            0.02   92758
# William     806955       50.05           50.0           17.36   73734
#
#                     City
# First Name
# Aaron            Eckerty
# Alan           Knoxville
# ...

# %%
df.loc['Amanda':'Andrea']
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Amanda      227922       35.02           40.0           10.28  114257
# Amy         893212       36.14           52.0           14.17  112715
# Andrea      183071       32.08           52.0            7.28   54179
#
#                     City
# First Name
# Amanda      Lake Charles
# Amy                Kline
# Andrea           Granger

# %%
df.loc['Amanda']
# Out:
# Emp ID                  227922
# Age in Yrs               35.02
# Weight in Kgs             40.0
# Age in Company           10.28
# Salary                  114257
# City              Lake Charles
# Name: Amanda, dtype: object

# %%
df.iloc[2:5]
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Amanda      227922       35.02           40.0           10.28  114257
# Amy         893212       36.14           52.0           14.17  112715
# Andrea      183071       32.08           52.0            7.28   54179
#
#                     City
# First Name
# Amanda      Lake Charles
# Amy                Kline
# Andrea           Granger

# %%
df.reset_index(inplace=True)
df
# Out:
#    First Name  Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0       Aaron  218791       48.49           56.0           20.08   54402
# 1        Alan  247137       38.65           80.0           11.15  154810
# 2      Amanda  227922       35.02           40.0           10.28  114257
# 3         Amy  893212       36.14           52.0           14.17  112715
# 4      Andrea  183071       32.08           52.0            7.28   54179
# ..        ...     ...         ...            ...             ...     ...
# 95    Theresa  214352       24.66           59.0            2.52  197537
# 96     Thomas  622406       49.85           73.0           19.15   73862
# 97       Todd  917937       25.93           74.0            1.22  163560
# 98      Wayne  301576       21.10           87.0            0.02   92758
# 99    William  806955       50.05           50.0           17.36   73734
#
#             City
# 0        Eckerty
# 1      Knoxville
# 2   Lake Charles
# 3          Kline
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02           60.0             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_values('Age in Yrs')
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 13  301576      Wayne       21.10           87.0            0.02   92758
# 49  879753     Pamela       21.30           47.0            0.13  149262
# 59  750173    Antonio       21.93           82.0            0.24  181646
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 11  153989       Jack       22.21           61.0            0.56   82965
# ..     ...        ...         ...            ...             ...     ...
# 74  528673       Paul       58.43           60.0           22.10  145235
# 7   380086      Carol       59.12           40.0           34.52   60918
# 57  515103       Anne       59.27           48.0           14.01  114426
# 24  560455    Carolyn       59.42           53.0           16.08   42005
# 14  441771     Cheryl       59.47           47.0           26.69   92220
#
#            City
# 13        Maida
# 49       Banner
# 59     Mc Calla
# 6       Atlanta
# ...

# %%
df.sort_values('Weight in Kgs',ascending=False)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 38  726264       Carl       43.63           90.0           10.14  162159
# 95  639892       Jose       22.82           89.0            1.05  129774
# 13  301576      Wayne       21.10           87.0            0.02   92758
# 82  761821     Ernest       32.77           87.0            2.49  176675
# 87  623929      Jimmy       50.70           87.0            9.63  120631
# ..     ...        ...         ...            ...             ...     ...
# 75  765850      Linda       25.96           40.0            0.20  113256
# 7   380086      Carol       59.12           40.0           34.52   60918
# 41  227922     Amanda       35.02           40.0           10.28  114257
# 0   677509       Lois       36.36            NaN           13.68  168251
# 3   408351      Diane       39.67            NaN           18.30  180294
#
#             City
# 38        Wright
# 95        Biloxi
# 13         Maida
# 82  Saranac Lake
# ...
