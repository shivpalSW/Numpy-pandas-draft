# %%
import pandas as pd
import numpy as np

# %% [raw]
# Append     df1.append(df2)
# concat     pd.concat([d1,d2])
# join       df1.join(df2)
# merge      df1.merge(df2) / pd.merge(df1,df2)

# %% [markdown]
# # Types of joins

# %% [markdown]
# ## Append()

# %% [markdown]
# ### along common rows

# %%
df1=pd.DataFrame({'ASCII Num':np.arange(65,71),
                  'char':[chr(i) for i in range(65,71)]})
df1
# Out:
#    ASCII Num char
# 0         65    A
# 1         66    B
# 2         67    C
# 3         68    D
# 4         69    E
# 5         70    F

# %%
df2=pd.DataFrame({'ASCII Num':np.arange(71,76),
                  'char':[chr(i) for i in range(71,76)]})
df2
# Out:
#    ASCII Num char
# 0         71    G
# 1         72    H
# 2         73    I
# 3         74    J
# 4         75    K

# %%
df1.append(df2)
# Out:
#    ASCII Num char
# 0         65    A
# 1         66    B
# 2         67    C
# 3         68    D
# 4         69    E
# 5         70    F
# 0         71    G
# 1         72    H
# 2         73    I
# 3         74    J
# 4         75    K

# %%
df1.append(df2,ignore_index=1)
# Out:
#     ASCII Num char
# 0          65    A
# 1          66    B
# 2          67    C
# 3          68    D
# 4          69    E
# 5          70    F
# 6          71    G
# 7          72    H
# 8          73    I
# 9          74    J
# 10         75    K

# %%
df3=pd.DataFrame({'ASCII Numbers':np.arange(71,76),
                  'char_new':[chr(i) for i in range(71,76)]})
df3
# Out:
#    ASCII Numbers char_new
# 0             71        G
# 1             72        H
# 2             73        I
# 3             74        J
# 4             75        K

# %%
display(df1,df3)
# Out:
#    ASCII Num char
# 0         65    A
# 1         66    B
# 2         67    C
# 3         68    D
# 4         69    E
# 5         70    F
#    ASCII Num char_new
# 0         71        G
# 1         72        H
# 2         73        I
# 3         74        J
# 4         75        K

# %%
df1.append(df3,ignore_index=True)
# Out:
#     ASCII Num char  ASCII Numbers char_new
# 0        65.0    A            NaN      NaN
# 1        66.0    B            NaN      NaN
# 2        67.0    C            NaN      NaN
# 3        68.0    D            NaN      NaN
# 4        69.0    E            NaN      NaN
# 5        70.0    F            NaN      NaN
# 6         NaN  NaN           71.0        G
# 7         NaN  NaN           72.0        H
# 8         NaN  NaN           73.0        I
# 9         NaN  NaN           74.0        J
# 10        NaN  NaN           75.0        K

# %%
df3=pd.DataFrame({'ASCII Num':np.arange(71,76),
                  'char':[chr(i) for i in range(71,76)]})
df3
# Out:
#    ASCII Num char
# 0         71    G
# 1         72    H
# 2         73    I
# 3         74    J
# 4         75    K

# %%
df1_T=df1.T
df1_T
df3_T=df3.T
df3_T
df1_T.append(df3_T)
# Out:
#             0   1   2   3   4    5
# ASCII Num  65  66  67  68  69   70
# char        A   B   C   D   E    F
# ASCII Num  71  72  73  74  75  NaN
# char        G   H   I   J   K  NaN

# %% [markdown]
# ### along common columns

# %%
df1.append(df3,ignore_index=1)
# Out:
#     ASCII Num char
# 0          65    A
# 1          66    B
# 2          67    C
# 3          68    D
# 4          69    E
# 5          70    F
# 6          71    G
# 7          72    H
# 8          73    I
# 9          74    J
# 10         75    K

# %%
df=pd.DataFrame(columns=['A'])
for i in range(5):
    df=df.append({'A':i},ignore_index=1) 
df
# Out:
#    A
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %% [markdown]
# ## concat

# %%
df4=pd.DataFrame({'ASCII Num':np.arange(71,76),
                  'char1':[chr(i) for i in range(71,76)]})
df4
# Out:
#    ASCII Num char1
# 0         71     G
# 1         72     H
# 2         73     I
# 3         74     J
# 4         75     K

# %%
display(df1,df2,df3,df4)
# Out:
#    ASCII Num char
# 0         65    A
# 1         66    B
# 2         67    C
# 3         68    D
# 4         69    E
# 5         70    F
#    ASCII Num char
# 0         71    G
# 1         72    H
# 2         73    I
# 3         74    J
# 4         75    K
#    ASCII Numbers char_new
# 0             71        G
# 1             72        H
# 2             73        I
# 3             74        J
# 4             75        K
#    ASCII Num char1
# 0         71     G
# 1         72     H
# 2         73     I
# 3         74     J
# 4         75     K

# %%
pd.concat([df1,df2],axis=0,ignore_index=1)
# Out:
#     ASCII Num char
# 0          65    A
# 1          66    B
# 2          67    C
# 3          68    D
# 4          69    E
# 5          70    F
# 6          71    G
# 7          72    H
# 8          73    I
# 9          74    J
# 10         75    K

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    ASCII Num char  ASCII Num char
# 0         65    A       71.0    G
# 1         66    B       72.0    H
# 2         67    C       73.0    I
# 3         68    D       74.0    J
# 4         69    E       75.0    K
# 5         70    F        NaN  NaN

# %%
pd.concat([df1,df3],axis=0,ignore_index=1)
# Out:
#     ASCII Num char  ASCII Numbers char_new
# 0        65.0    A            NaN      NaN
# 1        66.0    B            NaN      NaN
# 2        67.0    C            NaN      NaN
# 3        68.0    D            NaN      NaN
# 4        69.0    E            NaN      NaN
# 5        70.0    F            NaN      NaN
# 6         NaN  NaN           71.0        G
# 7         NaN  NaN           72.0        H
# 8         NaN  NaN           73.0        I
# 9         NaN  NaN           74.0        J
# 10        NaN  NaN           75.0        K

# %%
pd.concat([df1,df3],axis=1)
# Out:
#    ASCII Num char  ASCII Numbers char_new
# 0         65    A           71.0        G
# 1         66    B           72.0        H
# 2         67    C           73.0        I
# 3         68    D           74.0        J
# 4         69    E           75.0        K
# 5         70    F            NaN      NaN

# %%
pd.concat([df1,df4])
# Out:
#    ASCII Num char char1
# 0         65    A   NaN
# 1         66    B   NaN
# 2         67    C   NaN
# 3         68    D   NaN
# 4         69    E   NaN
# 5         70    F   NaN
# 0         71  NaN     G
# 1         72  NaN     H
# 2         73  NaN     I
# 3         74  NaN     J
# 4         75  NaN     K

# %%
##creating new dataframes for testing join function

# %%
join_1=pd.DataFrame({'ASCII Num':np.arange(71,76),
                  'char1':[chr(i) for i in range(71,76)]})
join_2=pd.DataFrame({'ASCII Num':np.arange(74,81),
                  'char2':[chr(i) for i in range(74,81)]})

# %%
display(join_1,join_2)
# Out:
#    ASCII Num char1
# 0         71     G
# 1         72     H
# 2         73     I
# 3         74     J
# 4         75     K
#    ASCII Num char2
# 0         74     J
# 1         75     K
# 2         76     L
# 3         77     M
# 4         78     N
# 5         79     O
# 6         80     P

# %%
pd.concat([join_1,join_2],axis=1,join='outer')
# Out:
#    ASCII Num char1  ASCII Num char2
# 0       71.0     G         74     J
# 1       72.0     H         75     K
# 2       73.0     I         76     L
# 3       74.0     J         77     M
# 4       75.0     K         78     N
# 5        NaN   NaN         79     O
# 6        NaN   NaN         80     P

# %%
pd.concat([join_1,join_2],axis=1,join='inner')
# Out:
#    ASCII Num char1  ASCII Num char2
# 0         71     G         74     J
# 1         72     H         75     K
# 2         73     I         76     L
# 3         74     J         77     M
# 4         75     K         78     N

# %%
join_1=pd.DataFrame({'ASCII Num':np.arange(71,76),
                  'char1':[chr(i) for i in range(71,76)]})
join_2=pd.DataFrame({'ASCII Num':np.arange(74,79),
                  'char2':['Z','Y','X','W','U']})

# %%
pd.concat([join_1,join_2],axis=0,join='inner')
# Out:
#    ASCII Num
# 0         71
# 1         72
# 2         73
# 3         74
# 4         75
# 0         74
# 1         75
# 2         76
# 3         77
# 4         78

# %%
pd.concat([join_1,join_2],axis=0,join='outer')
# Out:
#    ASCII Num char1 char2
# 0         71     G   NaN
# 1         72     H   NaN
# 2         73     I   NaN
# 3         74     J   NaN
# 4         75     K   NaN
# 0         74   NaN     J
# 1         75   NaN     K
# 2         76   NaN     L
# 3         77   NaN     M
# 4         78   NaN     N

# %%
pd.concat([join_1,join_2],axis=1,join='inner')
# Out:
#    ASCII Num  ASCII Num char2
# 0         71         74     J
# 1         72         75     K
# 2         73         76     L
# 3         74         77     M
# 4         75         78     N

# %% [markdown]
# ## Merge

# %%
join_1,join_2
# Out:
# (   ASCII Num char1
#  0         71     G
#  1         72     H
#  2         73     I
#  3         74     J
#  4         75     K,
#     ASCII Num char2
#  0         74     J
#  1         75     K
#  2         76     L
#  3         77     M
#  4         78     N)

# %%
pd.merge(join_1,join_2,how='inner')
# Out:
#    ASCII Num char1 char2
# 0         74     J     J
# 1         75     K     K

# %%
pd.merge(join_1,join_2,how='outer')
# Out:
#    ASCII Num char1 char2
# 0         71     G   NaN
# 1         72     H   NaN
# 2         73     I   NaN
# 3         74     J     J
# 4         75     K     K
# 5         76   NaN     L
# 6         77   NaN     M
# 7         78   NaN     N

# %%
pd.merge(join_1,join_2,how='left')
# Out:
#    ASCII Num char1 char2
# 0         71     G   NaN
# 1         72     H   NaN
# 2         73     I   NaN
# 3         74     J     J
# 4         75     K     K

# %%
pd.merge(join_1,join_2,how='right')
# Out:
#    ASCII Num char1 char2
# 0         74     J     J
# 1         75     K     K
# 2         76   NaN     L
# 3         77   NaN     M
# 4         78   NaN     N

# %%
x=join_1.merge(join_2,on='ASCII Num',how='left')
x
# Out:
#    ASCII Num char1 char2
# 0         71     G   NaN
# 1         72     H   NaN
# 2         73     I   NaN
# 3         74     J     J
# 4         75     K     K

# %%
x.reset_index()
# Out:
#    index  ASCII Num char1 char2
# 0      0         71     G   NaN
# 1      1         72     H   NaN
# 2      2         73     I   NaN
# 3      3         74     J     J
# 4      4         75     K     K

# %%
display(join_1,join_2)
# Out:
#    ASCII Num char1
# 0         71     G
# 1         72     H
# 2         73     I
# 3         74     J
# 4         75     K
#    ASCII Num char2
# 0         74     J
# 1         75     K
# 2         76     L
# 3         77     M
# 4         78     N

# %%
join_1.merge(join_2,on='ASCII Num',how='outer')
# Out:
#    ASCII Num char1 char2
# 0         71     G   NaN
# 1         72     H   NaN
# 2         73     I   NaN
# 3         74     J     J
# 4         75     K     K
# 5         76   NaN     L
# 6         77   NaN     M
# 7         78   NaN     N

# %%
join_1.rename(columns={'ASCII Num':'Numbers'},inplace=1)
join_1
# Out:
#    Numbers char1
# 0       71     G
# 1       72     H
# 2       73     I
# 3       74     J
# 4       75     K

# %%
join_2
# Out:
#    ASCII Num char2
# 0         74     J
# 1         75     K
# 2         76     L
# 3         77     M
# 4         78     N

# %%
join_1.merge(join_2,left_on='Numbers',right_on='ASCII Num',how='inner')
# Out:
#    Numbers char1  ASCII Num char2
# 0       74     J         74     J
# 1       75     K         75     K

# %%
join_1.merge(join_2,left_on='Numbers',right_on='ASCII Num',how='left')
# Out:
#    Numbers char1  ASCII Num char2
# 0       71     G        NaN   NaN
# 1       72     H        NaN   NaN
# 2       73     I        NaN   NaN
# 3       74     J       74.0     J
# 4       75     K       75.0     K

# %%
display(join_1,join_2)
# Out:
#    Numbers char1
# 0       71     G
# 1       72     H
# 2       73     I
# 3       74     J
# 4       75     K
#    ASCII Num char2
# 0         74     Z
# 1         75     Y
# 2         76     X
# 3         77     W
# 4         78     U

# %%
join_1.merge(join_2,on='ASCII Num',how='left')
# Out:
#    ASCII Num char1 char2
# 0         71     G   NaN
# 1         72     H   NaN
# 2         73     I   NaN
# 3         74     J     Z
# 4         75     K     Y

# %%
(join_1.merge(join_2,left_on='Numbers',right_on='ASCII Num',how='right')).drop('Numbers',axis=1)
# Out:
#   char1  ASCII Num char2
# 0     J         74     Z
# 1     K         75     Y
# 2   NaN         76     X
# 3   NaN         77     W
# 4   NaN         78     U

# %%
pd.merge(table1,table2)
table1.merge(table2)
