# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({'A':np.random.randint(10,20,size=5), 'B':[10,20,30,40,50],'C':np.random.randint(1,10,5)})

# %%
df1=df.copy()
df
# Out:
#     A   B  C
# 0  13  10  1
# 1  11  20  3
# 2  18  30  7
# 3  14  40  5
# 4  13  50  4

# %% [markdown]
# ## Apply()

# %% [raw]
# df.apply(function)

# %%
def square(array):
    array=array**2
    return array

# %%
square(4)
# Out:
# 16

# %%
df['C']=df['C'].apply(square)
df
# Out:
#     A   B     C
# 0  13  10     1
# 1  11  20    81
# 2  18  30  2401
# 3  14  40   625
# 4  13  50   256

# %%
df.apply(square)
# Out:
#      A     B        C
# 0  169   100        1
# 1  121   400     6561
# 2  324   900  5764801
# 3  196  1600   390625
# 4  169  2500    65536

# %%
df['C']=df['C'].apply(np.square)

# %%
df
# Out:
#     A   B   C
# 0  13  10   1
# 1  11  20   9
# 2  18  30  49
# 3  14  40  25
# 4  13  50  16

# %%
df.apply(lambda x:x**2)
# Out:
#      A     B     C
# 0  169   100     1
# 1  121   400    81
# 2  324   900  2401
# 3  196  1600   625
# 4  169  2500   256

# %%
df.apply(lambda x:x+2)
# Out:
#     A   B   C
# 0  15  12   3
# 1  13  22  11
# 2  20  32  51
# 3  16  42  27
# 4  15  52  18

# %%
new_df=pd.DataFrame({'A':('mumbai','pune','Delhi')})
new_df
# Out:
#         A
# 0  mumbai
# 1    pune
# 2   Delhi

# %%
def processing(s):
    return s.title()

new_df['A']=new_df['A'].apply(processing)

# %%
new_df
# Out:
#         A
# 0  Mumbai
# 1    Pune
# 2   Delhi

# %%
df=pd.read_csv('titanic.csv')
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Ticket.nunique()
# Out:
# 681

# %%
import re
def split_by_space(n):
    return (re.split(' ',n)[-1])

df['Ticket']=df['Ticket'].apply(split_by_space)

# %%
[i for i,item in enumerate(df.Ticket) if item=='LINE']
# Out:
# [179, 271, 302, 597]

# %%
df.drop([179, 271, 302, 597],axis=0,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Ticket=df.Ticket.astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 887 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  887 non-null    int64
#  1   Survived     887 non-null    int64
#  2   Pclass       887 non-null    int64
#  3   Name         887 non-null    object
#  4   Gender       887 non-null    object
#  5   Age          710 non-null    float64
#  6   SibSp        887 non-null    int64
#  7   Parch        887 non-null    int64
#  8   Ticket       887 non-null    int32
#  9   Fare         887 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     885 non-null    object
# dtypes: float64(2), int32(1), int64(5), object(4)
# memory usage: 86.6+ KB
