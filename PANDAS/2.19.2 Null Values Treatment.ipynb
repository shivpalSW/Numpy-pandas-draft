# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Emp_Records.csv')
df1=df.copy()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02           60.0             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      100 non-null    float64
#  3   Weight in Kgs   98 non-null     float64
#  4   Age in Company  99 non-null     float64
#  5   Salary          100 non-null    int64
#  6   City            100 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
df.isnull().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     2
# Age in Company    1
# Salary            0
# City              0
# dtype: int64

# %%
# detecting null values
# fill null values or use suitable algorithm
# drop null values

# %%
# df.isnull()
# df.isna()
# df.isnull().sum()
# df.isna().sum()
# df.fillna()
# df.dropna()
# df.drop()

# %%
df.dropna()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 7   380086      Carol       59.12           40.0           34.52   60918
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 4        Fremont
# 5      Macksburg
# 6        Atlanta
# ...

# %%
display(df.shape)
df
# Out:
# (100, 7)
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02           60.0             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# ...

# %%
df.fillna(100)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36          100.0           13.68  168251
# 1   940761     Brenda       47.02           60.0          100.00   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67          100.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df['Weight in Kgs'].fillna(65,inplace=True)

# %%
df['Age in Company']=df['Age in Company'].fillna(10)

# %%
df['Weight in Kgs'].mean()
# Out:
# 58.13265306122449

# %%
x=df['Weight in Kgs'].mean()
x
# Out:
# 58.13265306122449

# %%
df['Weight in Kgs'].fillna(x,inplace=True)
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36      58.132653           13.68  168251
# 1   940761     Brenda       47.02      60.000000           10.00   51063
# 2   428945        Joe       54.15      68.000000            0.98   50155
# 3   408351      Diane       39.67      58.132653           18.30  180294
# 4   193819   Benjamin       40.31      58.000000            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82      89.000000            1.05  129774
# 96  704709     Harold       32.61      77.000000            5.93  156194
# 97  461593     Nicole       52.66      60.000000           28.53   95673
# 98  392491    Theresa       29.60      57.000000            6.99   51015
# 99  495141      Tammy       38.38      55.000000            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df1
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02           60.0             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df1['Age in Company'].median()
# Out:
# 5.93

# %%
df1['Age in Company']=df1['Age in Company'].fillna(df1['Age in Company'].median())

# %%
df1.fillna(df.mean())
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36      58.132653           13.68  168251
# 1   940761     Brenda       47.02      60.000000            5.93   51063
# 2   428945        Joe       54.15      68.000000            0.98   50155
# 3   408351      Diane       39.67      58.132653           18.30  180294
# 4   193819   Benjamin       40.31      58.000000            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82      89.000000            1.05  129774
# 96  704709     Harold       32.61      77.000000            5.93  156194
# 97  461593     Nicole       52.66      60.000000           28.53   95673
# 98  392491    Theresa       29.60      57.000000            6.99   51015
# 99  495141      Tammy       38.38      55.000000            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...
