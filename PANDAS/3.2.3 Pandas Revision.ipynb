# %%
Data Structures:
    DataFrames
    Series
    
import
    pandas as pd
    
dataframe can be created using:
    array
    list,
    dict,
    tuple

how to import files
    reading csv
    reading excel
    json
    clipboard
    sql_query
    html
    
exporting:
    csv
    excel
    to_list
    
access, modify, delete
    loc,
    iloc
    slicing
    drop
    axis=0/1
    drop_duplicates
    replace
    del
    np.where
    set index
    reset index
    rename
    apply
    using loop, enumerate, in
    unique
    nunique
    info
    head
    tail
    axes
    index
    columns
    assign
    pop
    shape
    size
    value_counts
    dtypes
    astype
    type
    select_dtype
    shift
    transpose
    inplace
    ignnore_index
    to_datetime
    empty
    values
    

sorting:
    sort
    sort_index
    sort_values
    
mathematical operation
    sum
    len
    count
    mean
    median
    mode
    agg
    min
    max
    std
    var
    +,-,*,/,//,%,=,== etc.
    describe
    
    
    
dealing with null values
    drop_na
    fill_na
    isnull
    isna
    np.NaN
    thresold
    subset
    np.nan
    np.na
    
filters & conditions
    groupby, getgroup
    np.where
    loc, iloc
    &, |, ~
    
joining dataframes
    join
    merge
    append
    concat
    how
    on
    axis
    left_on
    right_on
    any
    all
    r_suffix
    l_suffix
    
parameters:
    set_index
    any
    all
    r_suffix
    l_suffix
    how
    on
    axis
    left_on
    right_on
    axis=0/1
    inplace
    ignnore_index
    thresold
    subset
