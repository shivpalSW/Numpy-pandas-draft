# %%
# df.isnull()
# df.isna()
# df.isnull().sum()
# df.isna().sum()
# df.fillna()
# df.dropna()
# df.drop()

# detecting null values
# fill null values or use suitable algorithm
# drop null values

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Emp_Records.csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.dropna(thresh=6)    #there should be at least 6 non null values
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ...

# %%
df.dropna(thresh=7)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 7   380086      Carol       59.12           40.0           34.52   60918
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 4        Fremont
# 5      Macksburg
# 6        Atlanta
# ...

# %%
df.dropna(thresh=5,axis=0)   #along axis 0 (rows) we need to have at least 5 non null values
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.dropna(thresh=98,axis=1)   #We need 98 non null values along the columns now. (axis=1)
# Out:
#     Emp ID First Name  Age in Yrs  Age in Company  Salary          City
# 0   677509       Lois       36.36           13.68  168251        Denver
# 1   940761     Brenda       47.02             NaN   51063     Stonewall
# 2   428945        Joe       54.15            0.98   50155  Michigantown
# 3   408351      Diane       39.67           18.30  180294      Hydetown
# 4   193819   Benjamin       40.31            4.01  117642       Fremont
# ..     ...        ...         ...             ...     ...           ...
# 95  639892       Jose       22.82            1.05  129774        Biloxi
# 96  704709     Harold       32.61            5.93  156194  Carol Stream
# 97  461593     Nicole       52.66           28.53   95673       Detroit
# 98  392491    Theresa       29.60            6.99   51015      Mc Grath
# 99  495141      Tammy       38.38            2.26   93650          Alma
#
# [100 rows x 6 columns]

# %%
df.drop('Weight in Kgs',axis=1)
# Out:
#     Emp ID First Name  Age in Yrs  Age in Company  Salary          City
# 0   677509       Lois       36.36           13.68  168251        Denver
# 1   940761     Brenda       47.02             NaN   51063     Stonewall
# 2   428945        Joe       54.15            0.98   50155  Michigantown
# 3   408351      Diane       39.67           18.30  180294      Hydetown
# 4   193819   Benjamin       40.31            4.01  117642       Fremont
# ..     ...        ...         ...             ...     ...           ...
# 95  639892       Jose       22.82            1.05  129774        Biloxi
# 96  704709     Harold       32.61            5.93  156194  Carol Stream
# 97  461593     Nicole       52.66           28.53   95673       Detroit
# 98  392491    Theresa       29.60            6.99   51015      Mc Grath
# 99  495141      Tammy       38.38            2.26   93650          Alma
#
# [100 rows x 6 columns]

# %%
df.drop(['Weight in Kgs','Age in Company'],axis=1)
# Out:
#     Emp ID First Name  Age in Yrs  Salary          City
# 0   677509       Lois       36.36  168251        Denver
# 1   940761     Brenda       47.02   51063     Stonewall
# 2   428945        Joe       54.15   50155  Michigantown
# 3   408351      Diane       39.67  180294      Hydetown
# 4   193819   Benjamin       40.31  117642       Fremont
# ..     ...        ...         ...     ...           ...
# 95  639892       Jose       22.82  129774        Biloxi
# 96  704709     Harold       32.61  156194  Carol Stream
# 97  461593     Nicole       52.66   95673       Detroit
# 98  392491    Theresa       29.60   51015      Mc Grath
# 99  495141      Tammy       38.38   93650          Alma
#
# [100 rows x 5 columns]

# %%
df.set_index('First Name').drop(['Brenda','Lois'],axis=0)
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Joe         428945       54.15           68.0            0.98   50155
# Diane       408351       39.67            NaN           18.30  180294
# Benjamin    193819       40.31           58.0            4.01  117642
# Patrick     499687       34.86           58.0           12.02   72305
# Nancy       539712       22.14           50.0            0.87   98189
# ...            ...         ...            ...             ...     ...
# Jose        639892       22.82           89.0            1.05  129774
# Harold      704709       32.61           77.0            5.93  156194
# Nicole      461593       52.66           60.0           28.53   95673
# Theresa     392491       29.60           57.0            6.99   51015
# Tammy       495141       38.38           55.0            2.26   93650
#
#                     City
# First Name
# Joe         Michigantown
# Diane           Hydetown
# ...

# %%
df.drop([0,1],axis=0)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# 5      Macksburg
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.dropna(subset=['Age in Company'])
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ...

# %%
df.dropna(subset=['Weight in Kgs', 'Age in Company'])
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 7   380086      Carol       59.12           40.0           34.52   60918
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 4        Fremont
# 5      Macksburg
# 6        Atlanta
# ...

# %%
df.dropna(subset=['Weight in Kgs', 'Age in Company'], how='any')
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15           68.0            0.98   50155
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 7   380086      Carol       59.12           40.0           34.52   60918
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 2   Michigantown
# 4        Fremont
# 5      Macksburg
# 6        Atlanta
# ...

# %%
df.dropna(subset=['Weight in Kgs', 'Age in Company'], how='all')
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
from statistics import mode
from scipy import stats

df['Age in Company'].mode()
# Out:
# 0    4.93
# dtype: float64

# %%
stats.mode(df['Age in Company'])[0][0]
# Out:
# 4.93

# %%
df['Age in Company'].fillna(stats.mode(df['Age in Company'])[0][0],inplace=True)
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN            4.93   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df['First Name'].mode()
# Out:
# 0    Nancy
# dtype: object
