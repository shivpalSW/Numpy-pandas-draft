# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## assign

# %%
any_num=[1,3,6,8]
df.assign(Random=any_num)
# Out:
#    Random
# 0       1
# 1       3
# 2       6
# 3       8

# %% [markdown]
# ## POP : will pop out a single coloumn.

# %%
df.pop('a')
# Out:
# 0    1
# 1    2
# 2    1
# 3    3
# Name: a, dtype: int64

# %%
df=pd.DataFrame({'a':[1,2,1,3],'b':[100,200,100,500]})
df
# Out:
#    a    b
# 0  1  100
# 1  2  200
# 2  1  100
# 3  3  500

# %% [markdown]
# ## values gives away the dataframe in numpy matrix format

# %%
df.values
# Out:
# array([[  1, 100],
#        [  2, 200],
#        [  1, 100],
#        [  3, 500]], dtype=int64)

# %%
##Reading from clipboard

# %%
df1=pd.read_clipboard()
df1
# Out:
#     Sku  ID Country Sub_Channel    Monthly       Mean   %  Weekly  Mean.1  %.1
# 0     0  -3      US    BadHabit   0.000000   0.000000 NaN     NaN     NaN  NaN
# 1     1  -3      US         REM   0.000000   0.000000 NaN     NaN     NaN  NaN
# 2     2  -3      US          JH   0.000000   0.000000 NaN     NaN     NaN  NaN
# 3     3  -3      US          PL   0.000000   0.000000 NaN     NaN     NaN  NaN
# 4     4  -3      US          US   0.000000   0.000000 NaN     NaN     NaN  NaN
# 5     5  -3      UK          UK  73.583906  73.583906 NaN     NaN     NaN  NaN
# 6     6  -3      UK          EU  26.416094  26.416094 NaN     NaN     NaN  NaN
# 7     7  -2      US    BadHabit   0.000000   0.000000 NaN     NaN     NaN  NaN
# 8     8  -2      US         REM   0.000000   0.000000 NaN     NaN     NaN  NaN
# 9     9  -2      US          JH   0.000000   0.000000 NaN     NaN     NaN  NaN
# 10   10  -2      US          PL   0.000000   0.000000 NaN     NaN     NaN  NaN
# ...

# %% [markdown]
# ## drop duplicates - dropping duplicate rows.

# %%
df.drop_duplicates()
# Out:
#    a    b
# 0  1  100
# 1  2  200
# 3  3  500

# %%
df['c']=[4,4,5,5]
df
# Out:
#    a    b  c
# 0  1  100  4
# 1  2  200  4
# 2  1  100  5
# 3  3  500  5

# %%
df.drop_duplicates(['a','b'])
# Out:
#    a    b  c
# 0  1  100  4
# 1  2  200  4
# 3  3  500  5

# %%
df.drop_duplicates(['a','b'])[['a','b']]
# Out:
#    a    b
# 0  1  100
# 1  2  200
# 3  3  500

# %%
df.drop_duplicates()
# Out:
#    a    b  c
# 0  1  100  4
# 1  2  200  4
# 2  1  100  5
# 3  3  500  5

# %%
df=pd.read_csv('movies_data.csv')
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
(df.drop_duplicates(['genre','content_rating']))[['genre','content_rating']]
# Out:
#          genre content_rating
# 0        Crime              R
# 3       Action          PG-13
# 5        Drama      NOT RATED
# 6      Western      NOT RATED
# 7    Adventure          PG-13
# ..         ...            ...
# 894    Mystery          PG-13
# 913     Horror              X
# 915      Crime          NC-17
# 936  Adventure            NaN
# 977     Horror             PG
#
# [98 rows x 2 columns]

# %%
len(df.groupby(['genre','content_rating']))
# Out:
# 98

# %%
df.drop_duplicates(['genre','content_rating']).shape[0]
# Out:
# 98

# %%
df.groupby(['genre','content_rating']).count()
# Out:
#                         star_rating  title  duration  actors_list
# genre   content_rating
# Action  APPROVED                  3      3         3            3
#         G                         1      1         1            1
#         GP                        1      1         1            1
#         NOT RATED                 4      4         4            4
#         PASSED                    1      1         1            1
# ...                             ...    ...       ...          ...
# Western APPROVED                  1      1         1            1
#         NOT RATED                 2      2         2            2
#         PG                        2      2         2            2
#         PG-13                     1      1         1            1
#         R                         3      3         3            3
#
# [95 rows x 4 columns]

# %%
for genre, subdf in df.groupby('genre'):
    display(genre,subdf)
#     subdf.to_excel(f'{genre} movies.csv')
# Out:
# 'Action'
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
df.groupby(['genre','content_rating']).sum()
# Out:
#                         star_rating    duration
# genre   content_rating
# Action  APPROVED           7.633333  143.333333
#         G                  7.800000  178.000000
#         GP                 7.700000  144.000000
#         NOT RATED          7.925000  129.500000
#         PASSED             7.700000   98.000000
# ...                             ...         ...
# Western APPROVED           8.300000  132.000000
#         NOT RATED          8.500000  151.000000
#         PG                 8.000000  110.000000
#         PG-13              8.600000  175.000000
#         R                  8.133333  133.666667
#
# [95 rows x 2 columns]

# %%
df['star_rating'].sum()
# Out:
# 7724.1

# %%
df['star_rating'].count()
# Out:
# 979

# %%
df['star_rating'].mean()
# Out:
# 7.8897854954034985

# %%
(df.drop(np.where(df['star_rating']==7.6)[0]))
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                r      Crime       142
# 1                r      Crime       175
# 2                r      Crime       200
# ...

# %%
### ~ is used to mention exclusing perticular condition. It is same as logical NOT

# %%
(df.drop(np.where(~(df['star_rating']==7.6))[0]))
# Out:
#      star_rating                         title content_rating      genre  \
# 698          7.6                     127 Hours              r  Adventure
# 699          7.6             The Fifth Element          PG-13     Action
# 700          7.6                          Milk              r  Biography
# 701          7.6                     United 93              r     Action
# 702          7.6         Jin ling shi san chai              r      Drama
# ..           ...                           ...            ...        ...
# 817          7.6              Saving Mr. Banks          PG-13  Biography
# 818          7.6                 The Hurricane              r  Biography
# 819          7.6                Jacob's Ladder              r      Drama
# 820          7.6  The Curse of the Were-Rabbit              G  Animation
# 821          7.6            Christmas Vacation          PG-13     Comedy
#
#      duration                                        actors_list
# ...

# %%
(df.drop(np.where(df['star_rating']==7.6)[0]))['star_rating'].unique()
# Out:
# array([9.3, 9.2, 9.1, 9. , 8.9, 8.8, 8.7, 8.6, 8.5, 8.4, 8.3, 8.2, 8.1,
#        8. , 7.9, 7.8, 7.7, 7.5, 7.4])

# %%
df['content_rating']=np.where(df['content_rating']=='R','r',np.NaN)
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                r      Crime       142
# 1                r      Crime       175
# 2                r      Crime       200
# ...

# %% [markdown]
# ### select perticular datatypes

# %%
df.select_dtypes('number')
# Out:
#      star_rating  duration
# 0            9.3       142
# 1            9.2       175
# 2            9.1       200
# 3            9.0       152
# 4            8.9       154
# ..           ...       ...
# 974          7.4       116
# 975          7.4       118
# 976          7.4       138
# 977          7.4       114
# 978          7.4       126
#
# [979 rows x 2 columns]

# %%
df.select_dtypes('object')
# Out:
#                                                title content_rating  \
# 0                           The Shawshank Redemption              r
# 1                                      The Godfather              r
# 2                             The Godfather: Part II              r
# 3                                    The Dark Knight          PG-13
# 4                                       Pulp Fiction              r
# ..                                               ...            ...
# 974                                          Tootsie             PG
# 975                      Back to the Future Part III             PG
# 976  Master and Commander: The Far Side of the World          PG-13
# 977                                      Poltergeist             PG
# 978                                      Wall Street              r
#
#          genre                                        actors_list
# 0        Crime  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
df.groupby('genre').nunique()
# Out:
#            star_rating  title  content_rating  duration  actors_list
# genre
# Action              16    136               9        65          134
# Adventure           15     74               8        59           68
# Animation           13     62               7        31           61
# Biography           15     77               7        52           77
# Comedy              13    156              11        62          156
# Crime               18    123               9        66          124
# Drama               16    278              11        94          278
# Family               2      2               2         2            2
# Fantasy              1      1               1         1            1
# Film-Noir            3      3               3         3            3
# History              1      1               1         1            1
# Horror              10     28               8        26           29
# ...

# %%
df.groupby('genre')['content_rating','star_rating'].nunique()
# Out:
# <ipython-input-53-bdfc082e5f84>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('genre')['content_rating','star_rating'].nunique()
#            content_rating  star_rating
# genre
# Action                  9           16
# Adventure               8           15
# Animation               7           13
# Biography               7           15
# Comedy                 11           13
# Crime                   9           18
# Drama                  11           16
# Family                  2            2
# Fantasy                 1            1
# Film-Noir               3            3
# History                 1            1
# Horror                  8           10
# Mystery                 7           11
# Sci-Fi                  3            5
# Thriller                3            4
# Western                 5            7

# %% [markdown]
# ## agg function

# %%
df.groupby(['genre'])['star_rating','content_rating'].agg(['nunique','count'])
# Out:
# <ipython-input-64-b848b6396e75>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['genre'])['star_rating','content_rating'].agg(['nunique','count'])
#           star_rating       content_rating
#               nunique count        nunique count
# genre
# Action             16   136              9   135
# Adventure          15    75              8    74
# Animation          13    62              7    62
# Biography          15    77              7    76
# Comedy             13   156             11   156
# Crime              18   124              9   124
# Drama              16   278             11   278
# Family              2     2              2     2
# Fantasy             1     1              1     1
# Film-Noir           3     3              3     3
# History             1     1              1     1
# Horror             10    29              8    29
# ...
