# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('movies_data.csv')
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
df.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
df.groupby('genre')

# %%
for genre, subdf in df.groupby('genre'):
    display(genre,subdf)
# Out:
# 'Action'
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
df.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
df.content_rating.value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# NC-17          7
# PASSED         7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
df.groupby('genre').first()
# Out:
#            star_rating                                          title  \
# genre
# Action             9.0                                The Dark Knight
# Adventure          8.9  The Lord of the Rings: The Return of the King
# Animation          8.6                                  Spirited Away
# Biography          8.9                               Schindler's List
# Comedy             8.6                              Life Is Beautiful
# Crime              9.3                       The Shawshank Redemption
# Drama              8.9                                   12 Angry Men
# Family             7.9                     E.T. the Extra-Terrestrial
# Fantasy            7.7                      The City of Lost Children
# Film-Noir          8.3                                  The Third Man
# History            8.0                            Battleship Potemkin
# Horror             8.6                                         Psycho
# ...

# %%
df.groupby('genre').last()
# Out:
#            star_rating                                            title  \
# genre
# Action             7.4  Master and Commander: The Far Side of the World
# Adventure          7.4                      Back to the Future Part III
# Animation          7.4                               The Simpsons Movie
# Biography          7.4                                          Lincoln
# Comedy             7.4                                          Tootsie
# Crime              7.4                                      Wall Street
# Drama              7.4                            The Cider House Rules
# Family             7.8              Willy Wonka & the Chocolate Factory
# Fantasy            7.7                        The City of Lost Children
# Film-Noir          7.7                                       Spellbound
# History            8.0                              Battleship Potemkin
# Horror             7.4                                      Poltergeist
# ...

# %%
df1=df.groupby('genre').get_group('Action')

# %%
df.groupby('genre').get_group('Action')['genre'].unique()
# Out:
# array(['Action'], dtype=object)

# %%
df1.groupby('content_rating').get_group('R')
# Out:
#      star_rating                       title content_rating   genre  duration  \
# 20           8.7                  The Matrix              R  Action       136
# 36           8.6         Saving Private Ryan              R  Action       169
# 44           8.5                   Gladiator              R  Action       155
# 45           8.5  Terminator 2: Judgment Day              R  Action       137
# 75           8.4                      Aliens              R  Action       137
# ..           ...                         ...            ...     ...       ...
# 885          7.5                Total Recall              R  Action       113
# 906          7.5                      Looper              R  Action       119
# 918          7.5              Running Scared              R  Action       122
# 963          7.4             La Femme Nikita              R  Action       118
# 967          7.4                    The Rock              R  Action       136
#
# ...

# %%
df.groupby(['genre','content_rating']).get_group(('Comedy','PG'))
# Out:
#      star_rating                                              title  \
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 97           8.4                                          The Sting
# 208          8.1                                         Annie Hall
# 266          8.1                                  A Christmas Story
# 275          8.1                                      Groundhog Day
# 280          8.1                                 Young Frankenstein
# 304          8.0                                        Being There
# 516          7.8                                       Ghostbusters
# 524          7.8                                          Airplane!
# 535          7.8                                              Zelig
# 565          7.8                                        The Sandlot
# 580          7.8                                 The King of Comedy
# 590          7.7                                            Flipped
# ...

# %%
df.loc[df.genre=='Family']
# Out:
#      star_rating                                title content_rating   genre  \
# 468          7.9           E.T. the Extra-Terrestrial             PG  Family
# 497          7.8  Willy Wonka & the Chocolate Factory              G  Family
#
#      duration                                        actors_list
# 468       115  [u'Henry Thomas', u'Drew Barrymore', u'Peter C...
# 497       100  [u'Gene Wilder', u'Jack Albertson', u'Peter Os...

# %%
df.loc[(df.genre=='Crime')&((df.content_rating=='PG')|(df.content_rating=='APPROVED'))&(df.duration>=120)]
# Out:
#      star_rating                  title content_rating  genre  duration  \
# 154          8.2         Cool Hand Luke             PG  Crime       126
# 495          7.8  The Day of the Jackal             PG  Crime       143
#
#                                            actors_list
# 154  [u'Paul Newman', u'George Kennedy', u'Strother...
# 495  [u'Edward Fox', u'Terence Alexander', u'Michel...

# %%
df.loc[(df.genre=='Crime')&(df.content_rating=='G')]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
df.loc[(df.duration>=120)&(df.duration<=150)]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# ..           ...                                              ...
# 964          7.4                                          Lincoln
# 967          7.4                                         The Rock
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 9                R      Drama       139
# 11           PG-13     Action       148
# ...
