# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('titanic.csv')
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
len(df['Gender'].unique())
# Out:
# 2

# %%
df.groupby('Gender').get_group('male').shape[0],df.groupby('Gender').get_group('female').shape[0]
# Out:
# (577, 314)

# %%
df['Gender'].value_counts()[0]
# Out:
# 577

# %%
# Out:
# 111

# %%
df.groupby(['Survived','Gender']).get_group((1,'female')).shape[0]
# Out:
# 233

# %%
(df.groupby(['Survived','Gender']).get_group((1,'male')).shape[0]/df['Gender'].value_counts()[0])*100
# Out:
# 19.23743500866551

# %%
(df.groupby(['Survived','Gender']).get_group((1,'female')).shape[0]/df['Gender'].value_counts()[1])*100
# Out:
# 74.20382165605095

# %%
df['Survived'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## astype

# %%
df['Survived']=df['Survived'].astype('float')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df=pd.DataFrame({'A':np.random.randint(10,20,size=5), 'B':[10,20,30,40,50]})
df
# Out:
#     A   B
# 0  14  10
# 1  15  20
# 2  13  30
# 3  14  40
# 4  11  50

# %%
df['C']='Python'
df
# Out:
#     A   B       C
# 0  19  10  Python
# 1  10  20  Python
# 2  12  30  Python
# 3  17  40  Python
# 4  17  50  Python

# %%
df['D']=df['A']+df['B']
df
# Out:
#     A   B       C   D
# 0  19  10  Python  29
# 1  10  20  Python  30
# 2  12  30  Python  42
# 3  17  40  Python  57
# 4  17  50  Python  67

# %%
df['C']=np.random.randint(1,10,5)
df
# Out:
#      A   B  C
# 0  14%  10  8
# 1  15%  20  5
# 2  13%  30  9
# 3  14%  40  7
# 4  11%  50  9

# %%
df["E"]=(df['A']*df['B'])/df['C']
df
# Out:
#     A   B  C   D           E
# 0  19  10  9  29   21.111111
# 1  10  20  1  30  200.000000
# 2  12  30  8  42   45.000000
# 3  17  40  6  57  113.333333
# 4  17  50  1  67  850.000000

# %%
df
# Out:
#     A   B
# 0  14  10
# 1  15  20
# 2  13  30
# 3  14  40
# 4  11  50

# %%
df['A']=df['A'].astype('str')
df['A'].dtype
# Out:
# dtype('O')

# %%
df['A']=df['A']+'%'
df
# Out:
#      A   B
# 0  14%  10
# 1  15%  20
# 2  13%  30
# 3  14%  40
# 4  11%  50

# %% [markdown]
# ## insert

# %%
df.insert(location_index, column_name, column_values)

# %%
df=pd.DataFrame({'A':np.random.randint(10,20,size=5), 'B':[10,20,30,40,50],'C':np.random.randint(1,10,5)})
df1=df.copy()
df
# Out:
#     A   B  C
# 0  15  10  4
# 1  19  20  4
# 2  14  30  1
# 3  18  40  7
# 4  14  50  7

# %%
df.insert(3,'D',[1,3,2,5,9])

# %%
df.insert(1,'a',1000)
df
# Out:
#     A     a   B  C  D
# 0  19  1000  10  5  1
# 1  17  1000  20  9  3
# 2  14  1000  30  1  2
# 3  15  1000  40  5  5
# 4  17  1000  50  5  9

# %%
df1=df.T
df1.insert(0,'-1',np.random.randint(1,5,5))
df1
# Out:
#    -1     0     1     2     3     4
# A   3    19    17    14    15    17
# a   2  1000  1000  1000  1000  1000
# B   2    10    20    30    40    50
# C   2     5     9     1     5     5
# D   3     1     3     2     5     9

# %%
df1.T
# Out:
#      A     a   B  C  D
# -1   3     2   2  2  3
# 0   19  1000  10  5  1
# 1   17  1000  20  9  3
# 2   14  1000  30  1  2
# 3   15  1000  40  5  5
# 4   17  1000  50  5  9

# %% [markdown]
# ## Rename

# %%
df.rename({'a':'E'},axis=1)
# Out:
#     A     E   B  C  D
# 0  19  1000  10  5  1
# 1  17  1000  20  9  3
# 2  14  1000  30  1  2
# 3  15  1000  40  5  5
# 4  17  1000  50  5  9

# %%
df.rename({0:-1},axis=0)
# Out:
#      A     a   B  C  D
# -1  19  1000  10  5  1
#  1  17  1000  20  9  3
#  2  14  1000  30  1  2
#  3  15  1000  40  5  5
#  4  17  1000  50  5  9

# %%
df.rename(columns={'a':'E','B':'F','C':'G'},inplace=True)
# Out:
#     A     E   F  G  D
# 0  19  1000  10  5  1
# 1  17  1000  20  9  3
# 2  14  1000  30  1  2
# 3  15  1000  40  5  5
# 4  17  1000  50  5  9

# %%
df
# Out:
#     A     a   B  C  D
# 0  19  1000  10  5  1
# 1  17  1000  20  9  3
# 2  14  1000  30  1  2
# 3  15  1000  40  5  5
# 4  17  1000  50  5  9

# %%
df.rename({0:-1,1:0},axis=0)
# Out:
#      A     a   B  C  D
# -1  19  1000  10  5  1
#  0  17  1000  20  9  3
#  2  14  1000  30  1  2
#  3  15  1000  40  5  5
#  4  17  1000  50  5  9

# %%
df.A=df.A.shift(-1)
df
# Out:
#       A     a   B  C  D
# 0  17.0  1000  10  5  1
# 1  14.0  1000  20  9  3
# 2  15.0  1000  30  1  2
# 3  17.0  1000  40  5  5
# 4   NaN  1000  50  5  9

# %%
df.A=df.A.shift(2)
df
# Out:
#       A     a   B  C  D
# 0   NaN  1000  10  5  1
# 1   NaN  1000  20  9  3
# 2  17.0  1000  30  1  2
# 3  14.0  1000  40  5  5
# 4  15.0  1000  50  5  9

# %%
df.index=df.index+2
df
# Out:
#       A     a   B  C  D
# 1   NaN  1000  10  5  1
# 2   NaN  1000  20  9  3
# 3  17.0  1000  30  1  2
# 4  14.0  1000  40  5  5
# 5  15.0  1000  50  5  9

# %%
df=df.shift(1)
df.loc[1:]
# Out:
#       A     B    C
# 1  19.0  10.0  4.0
# 2  12.0  20.0  5.0
# 3  15.0  30.0  5.0
# 4  16.0  40.0  8.0

# %%
df.columns=['B','A','C']   #changing the coloum names but not changing sqitching the values of the columns
df
# Out:
#       B     A    C
# 0   NaN   NaN  NaN
# 1  19.0  10.0  4.0
# 2  12.0  20.0  5.0
# 3  15.0  30.0  5.0
# 4  16.0  40.0  8.0

# %%
df1
# Out:
#     A   B  C
# 0  19  10  4
# 1  12  20  5
# 2  15  30  5
# 3  16  40  8
# 4  12  50  8

# %%
df1 = df1[['C', 'A', 'B']]    ## changing the sequence of the columns along with their values
df1
# Out:
#    C   A   B
# 0  4  19  10
# 1  5  12  20
# 2  5  15  30
# 3  8  16  40
# 4  8  12  50

# %%
df1.loc[[4,3,0,2,1]]    ## changing the sequence of the rows along with their values
# Out:
#     A   B  C
# 4  14  50  7
# 3  18  40  7
# 0  15  10  4
# 2  14  30  1
# 1  19  20  4
